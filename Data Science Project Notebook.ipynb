# %% [markdown]
# # Data Science Project Notebook

# %% [markdown]
# ## Introduction
# In this notebook, we explore various aspects of Data Science, including languages, libraries, and tools.

# %% [markdown]
# ## Data Science Languages
# - Python
# - R
# - SQL

# %% [markdown]
# ## Data Science Libraries
# - NumPy
# - Pandas
# - Matplotlib
# - Scikit-learn

# %% [markdown]
# ## Data Science Tools
#
# | Tool            | Purpose                  |
# |-----------------|--------------------------|
# | Jupyter         | Interactive computing    |
# | GitHub          | Version control          |
# | Docker          | Containerization         |
# | TensorFlow      | Machine learning         |

# %% [markdown]
# ## Arithmetic Expression Examples
# Here are some examples of arithmetic expressions in Python:

# %%
# Code to multiply and add numbers
a = 5
b = 3
result = (a * b) + (a + b)
result
# Out:
# 23

# %%
# Code to convert minutes to hours
minutes = 150
hours = minutes / 60
hours
# Out:
# 2.5

# %% [markdown]
# ## Objectives
# - Learn data science languages.
# - Explore data science libraries.
# - Understand data science tools.

# %% [markdown]
# ## Author
# Vathsala Sivapalan
